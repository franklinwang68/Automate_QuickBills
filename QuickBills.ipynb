# %% [markdown]
# ### Procedures
#
# 1. Initial set up - vendor, total invoice amount, invoice date, bill invoice number, yes: create payable.
# 2. Enter Payables
#     1. Enter and select related object on last row
#     2. service date - month, day, year
#     3. payable type
#     4. amount
#     5. edit payble - shift tab shit tab
#     6. invoice number
#     7. transaction date
#     8. yes, pay in full
#     9. save
#
#
# ### Code:
# initial data
# 1. read csv file and parse dates
# 2. set transaction date
#
# Enter payables
# 1. mouse click related object on last row (Wait before and after click).
#     1. manual click, auto write, wait, down, tab,
# 2. servmonth, tab, servday, tab, servyear, tab,
# 3. payble type: pp (unless agreement) tab, tab
# 4. write amount tab enter
# 5. wait
# 6. shift tab shift tab wait
# 7. tab x times, write invoice, tab x4
# 8. transmonth, tab, transday, tab, transyear, tab
# 9. tab x times, down, enter

# %%
import pyautogui
import time
import csv

# %%
#Transaction Date
transactDay = '6'
transactMonth = 'Jan' #3 letter month
transactYear = '2025'
payable_type = "pat"  # set to "agreement" manually if needed

manual_click_target_row = False

# %%
#Main Code

## about 50 records in 30 minutes

# === STEP 0: Initial Prep ===
print("Starting automation in 5 seconds — switch to the target window.")
time.sleep(5)

# === Load CSV ===
with open('data.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    
    for row in reader:
        # Extract fields from current CSV row
        case_number = row['Case Number']
        serv_month = row['Service Month']
        serv_day = row['Service Day']
        serv_year = row['Service Year']
        amount = row['Invoice Total']
        invoice = row['Invoice Number']

        print(f"Entering record: {invoice} ",end="")

        # === STEP 1: Go to target row ===
        if(manual_click_target_row):
            wait = 3
            print(f"Click target row within {wait} seconds.")
            time.sleep(wait)
        else:
            pyautogui.press('end')
            ### place cursor at target, don't move it
            time.sleep(2)
            pyautogui.click()

        print("Creating Payable... ", end="")
        # === STEP 2: Write case number ===
        pyautogui.write(case_number)
        time.sleep(7)
        pyautogui.press('down')
        pyautogui.press('tab')

        # === STEP 3: Service Date ===
        pyautogui.write(serv_month)
        pyautogui.press('tab')
        pyautogui.write(serv_day, interval=.5) 
        # In Sofia, pressing "1" and "1", the second "1" key acts like a down arrow. 
        # It will also do it whent the prior value is a single digit or between 10-19. 
        # This can be tested by entering "11" into the day field. The same occurs with "22"
        if (serv_day == '11'):
            pyautogui.press('down')
        if (serv_day == '22'):
            pyautogui.press('down')
            pyautogui.press('down')
        pyautogui.press('tab')
        pyautogui.write(serv_year)
        pyautogui.press('tab')

        # === STEP 4: Payable Type ===
        pyautogui.write(payable_type)
        pyautogui.press('tab')
        pyautogui.press('tab')

        # === STEP 5: Amount + Submit ===
        pyautogui.write(amount)
        pyautogui.press('tab')
        pyautogui.press('enter')

        print("Editing payable... ", end="")

        # === STEP 6: Edit Payable ===
        pyautogui.hotkey('shift', 'tab')
        pyautogui.hotkey('shift', 'tab')
        pyautogui.press('enter')
        time.sleep(7)

        # === STEP 7: Write invoice ===
        for _ in range(24):
            pyautogui.press('tab')
        pyautogui.write(invoice)

        # === STEP 8: Transaction Date ===
        for _ in range(4):
            pyautogui.press('tab')
        pyautogui.write(transactMonth)
        pyautogui.press('tab')

        ### Writing transact day
        # If day is 11 or 22 or single digit, need to reset it to default "- DAY -"
        for _ in range(31): 
           pyautogui.press('up')
        pyautogui.write(transactDay)

        if(transactDay == '11'): # special case 11
            pyautogui.press('down') 
        elif(transactDay == '22'): # special case 22
            pyautogui.press('down') 
            pyautogui.press('down') 
        
        pyautogui.press('tab')
        pyautogui.write(transactYear)
        pyautogui.press('tab')

        # === STEP 9: Yes, pay in full ===
        for _ in range(15):
            pyautogui.press('tab')
        pyautogui.press('down')
        pyautogui.press('enter')

        time.sleep(15)  # delay before next record
        print(f"✅ Finished: {invoice}")

print("✅ All records processed. Please Ensure all dates with 11 and 22 are entered correctly.")
# Out:
# Starting automation in 5 seconds — switch to the target window.
# Entering record: 537012 Creating Payable... Editing payable... ✅ Finished: 537012
# Entering record: 537013 Creating Payable... Editing payable... ✅ Finished: 537013
# Entering record: 537014 Creating Payable... Editing payable... ✅ Finished: 537014
# Entering record: 537015 Creating Payable... Editing payable... ✅ Finished: 537015
# Entering record: 537016 Creating Payable... Editing payable... ✅ Finished: 537016
# Entering record: 537017 Creating Payable... Editing payable... ✅ Finished: 537017
# Entering record: 537018 Creating Payable... Editing payable... ✅ Finished: 537018
# Entering record: 537019 Creating Payable... Editing payable... ✅ Finished: 537019
# Entering record: 537020 Creating Payable... Editing payable... ✅ Finished: 537020
# Entering record: 537021 Creating Payable... Editing payable... ✅ Finished: 537021
# Entering record: 537022 Creating Payable... Editing payable... ✅ Finished: 537022
# Entering record: 537023 Creating Payable... Editing payable... ✅ Finished: 537023
# Entering record: 537024 Creating Payable... Editing payable... ✅ Finished: 537024
# Entering record: 537026 Creating Payable... Editing payable... ✅ Finished: 537026
# Entering record: 537027 Creating Payable... Editing payable... ✅ Finished: 537027
# Entering record: 537029 Creating Payable... Editing payable... ✅ Finished: 537029
# Entering record: 537053 Creating Payable... Editing payable... ✅ Finished: 537053
# Entering record: 537054 Creating Payable... Editing payable... ✅ Finished: 537054
# Entering record: 537198 Creating Payable... Editing payable... ✅ Finished: 537198
# Entering record: 537229 Creating Payable... Editing payable... ✅ Finished: 537229
# Entering record: 537243 Creating Payable... Editing payable... ✅ Finished: 537243
# Entering record: 537422 Creating Payable... Editing payable... ✅ Finished: 537422
# Entering record: 536612
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# Cell In[17], line 33
#      31     ### place cursor at target, don't move it
#      32     time.sleep(2)
# ---> 33     pyautogui.click()
#      35 print("Creating Payable... ", end="")
#      36 # === STEP 2: Write case number ===
#
# File c:\Users\nanhu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyautogui\__init__.py:593, in _genericPyAutoGUIChecks.<locals>.wrapper(*args, **kwargs)
#     591 @functools.wraps(wrappedFunction)
#     592 def wrapper(*args, **kwargs):
# --> 593     failSafeCheck()
#     594     returnVal = wrappedFunction(*args, **kwargs)
#     595     _handlePause(kwargs.get("_pause", True))
#
# File c:\Users\nanhu\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyautogui\__init__.py:1734, in failSafeCheck()
#    1732 def failSafeCheck():
#    1733     if FAILSAFE and tuple(position()) in FAILSAFE_POINTS:
# -> 1734         raise FailSafeException(
#    1735             "PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED."
#    1736         )
#
# FailSafeException: PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.
